# %%
import pong
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pong.RED
# Out:
# (255, 0, 0)

# %%
pong.SIGN_BALL
# Out:
# 'o'

# %%
pong.init_pong()
# Out:
# Pong init

# %%
import pygame
import numpy as np
from tqdm import tqdm
import pong

print(pong.RED)
print(pong.ACTIONS)
print(pong.init_pong())
# Out:
# (255, 0, 0)
# ['IDLE', 'LEFT', 'RIGHT']
# Pong init
# None

# %%
from qla import QLearningAgent

pong.agent = QLearningAgent(n_states=pong.num_states, n_actions=3, learning_rate=1.0)
print(pong.agent)
# Out:
# <qla.QLearningAgent object at 0x000001BF6C708460>

# %%
import pong as pong
pong.init_pong()

from qla import QLearningAgent

pong.agent = QLearningAgent(n_states=pong.num_states, n_actions=3, learning_rate=1.0)
pong.agent

# a jatek fo kore
clock = pong.pygame.time.Clock()

rewards, epsilon_history = pong.play_episodes(
    n_episodes=50_000,
    max_epsilon=1.0,
    min_epsilon=0.05,
    decay_rate=0.0001,
    gamma=0.95,
    learn=True,
    viz=False,
    human=False,
    log=False
)

import matplotlib.pyplot as plt

#ellenőrízhetjük az ügynök teljestményéne történetét
plt.plot(epsilon_history)
plt.show()

plt.plot(rewards)
plt.show()

import pickle

with open("agent.pkl","rb") as f:
    pong.agent = pickle.load(f)
with open("state_to_id.pkl","rb") as f:
    pong.state_to_id = pickle.load

#most megfigyelhetjük hogy teljesít a képzett agent
rewards, epsilon_history = pong.play_episodes(10,max_epsilon=0,min_epsilon=0,decay_rate=0,gamma=0,learn=False,viz=True,log=True)
plt.plot(epsilon_history)
plt.show()

with open("agent.pkl","wb") as f:
    pickle.dump(pong.agent,f)
with open("state_to_id.pkl","wb") as f:
    pickle.dump(pong.state_to_id,f)
# Out:
# Pong init
# 100%|██████████| 50000/50000 [06:26<00:00, 129.46it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 35
#      31 plt.show()
#      33 import pickle
# ---> 35 with open("agent.pkl","rb") as f:
#      36     pong.agent = pickle.load(f)
#      37 with open("state_to_id.pkl","rb") as f:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'agent.pkl'

# %%
from IPython.display import Image
from IPython.display import Video

from sklearn.datasets import fetch_openml
mnist = fetch_openml(name="mnist_784")

print(mnist.keys())

data = mnist.data
labels = mnist.target

print(data.shape)
